# %% [markdown]
# # Języki Obiektowe I - Python

# %% [markdown]
# **Filip Koźlik** \\
# *Informatyka st. II hybrydowo*

# %% [markdown]
# **Task 1**
# 1. load the file teachers.csv, which contains data on the employment of university teachers in Poland in selected years
# selected years, broken down by position and gender. Universities and technical schools are further distinguished.
# 2. prepare the data for further analysis (remove unnecessary rows and columns, pay attention to the type of data).
# 3. create the following charts:
# - summary of academic teachers employed in any position in 2014-2018 by province
# - summary of different positions (assistants, adjuncts, professors) employed in 2014-2018 in the province of
# śląskie
# - summary of academic teachers employed at universities and technical schools by gender
# in Silesia province
# 4. in the data find:
# - values for Silesian province
# - provinces that employ the most and the least academic teachers
# - provinces that employ women above the average

# %% [markdown]
# **List o needed imports**
# 1. Plotly.express - data ploting,
# 2. Pandas - data manipulation,
# 3. Typing - Type hints, syntax.

# %%
import plotly.express as px
import pandas as pd
from typing import Final, Tuple

# %% [markdown]
# # Task 1 and 2

# %% [markdown]
# **Data loading and preppering**

# %%
TEACHERS_DATA_CSV_PATH: Final[str] = r'/content/nauczyciele.csv'

df: pd.DataFrame = pd.read_csv(TEACHERS_DATA_CSV_PATH, delimiter=';')
df = df.drop(columns = ['Kod', 'Unnamed: 102'])
df = df.iloc[1:,:]
for col in list(df.columns)[1:]:
  df[col] = df[col].apply(lambda x: x.replace(',', '.'))
  df[col] = df[col].astype(float)
df
# Out:
#                   Nazwa  \
# 1          DOLNOŚLĄSKIE
# 2    KUJAWSKO-POMORSKIE
# 3             LUBELSKIE
# 4              LUBUSKIE
# 5               ŁÓDZKIE
# 6           MAŁOPOLSKIE
# 7           MAZOWIECKIE
# 8              OPOLSKIE
# 9          PODKARPACKIE
# 10            PODLASKIE
# 11            POMORSKIE
# 12              ŚLĄSKIE
# 13       ŚWIĘTOKRZYSKIE
# 14  WARMIŃSKO-MAZURSKIE
# 15        WIELKOPOLSKIE
# 16   ZACHODNIOPOMORSKIE
#
#     nauczyciele akademiccy;ogółem;uniwersytety;2014;[osoba]  \
# 1                                              1837.7
# 2                                              2689.9
# 3                                              2912.0
# 4                                               899.0
# 5                                              2188.2
# 6                                              3879.4
# 7                                              4196.0
# 8                                               696.4
# 9                                              1275.8
# 10                                              776.1
# 11                                             1670.6
# 12                                             1940.9
# 13                                              856.0
# 14                                             1994.0
# 15                                             2963.9
# 16                                             1152.2
#
#     nauczyciele akademiccy;ogółem;uniwersytety;2015;[osoba]  \
# 1                                              1856.7
# 2                                              2651.1
# 3                                              2770.8
# 4                                               884.5
# 5                                              2159.2
# 6                                              3932.9
# 7                                              4259.0
# 8                                               688.7
# 9                                              1290.1
# 10                                              753.8
# 11                                             1700.5
# 12                                             1941.2
# 13                                              850.4
# 14                                             1924.1
# 15                                             2918.3
# 16                                             1118.9
#
#     nauczyciele akademiccy;ogółem;uniwersytety;2016;[osoba]  \
# 1                                              1884.5
# 2                                              2647.4
# 3                                              2721.5
# 4                                               920.0
# 5                                              2145.6
# 6                                              4022.4
# 7                                              4303.5
# 8                                               678.0
# 9                                              1306.6
# 10                                              747.7
# 11                                             1685.8
# 12                                             1950.4
# 13                                              872.4
# 14                                             1908.2
# 15                                             2929.8
# 16                                             1114.7
#
#     nauczyciele akademiccy;ogółem;uniwersytety;2017;[osoba]  \
# 1                                              1919.2
# 2                                              2721.4
# 3                                              2648.5
# 4                                              1000.5
# 5                                              2157.7
# 6                                              4119.2
# 7                                              4332.0
# 8                                               687.3
# 9                                              1299.0
# 10                                              760.9
# 11                                             1720.9
# 12                                             1930.2
# 13                                              885.1
# 14                                             1834.5
# 15                                             2881.9
# 16                                             1093.0
#
#     nauczyciele akademiccy;ogółem;uniwersytety;2018;[osoba]  \
# 1                                              1930.9
# 2                                              2684.8
# 3                                              2578.0
# 4                                               982.5
# 5                                              2135.4
# 6                                              4120.7
# 7                                              4285.4
# 8                                               666.1
# 9                                              1253.7
# 10                                              763.3
# 11                                             1735.4
# 12                                             1887.7
# 13                                              868.1
# 14                                             1791.8
# 15                                             2843.7
# 16                                             1033.3
#
#     nauczyciele akademiccy;ogółem;wyższe szkoły techniczne;2014;[osoba]  \
# 1                                              2003.3
# 2                                                 0.0
# 3                                               549.0
# 4                                                 0.0
# 5                                              1432.6
# 6                                              3444.0
# 7                                              3055.9
# 8                                               504.2
# 9                                               771.0
# 10                                              663.7
# 11                                             1220.7
# 12                                             3040.3
# 13                                              474.3
# 14                                                0.0
# 15                                             1278.8
# 16                                             1521.8
#
#     nauczyciele akademiccy;ogółem;wyższe szkoły techniczne;2015;[osoba]  \
# 1                                              2028.6
# 2                                                 0.0
# 3                                               568.9
# 4                                                 0.0
# 5                                              1396.4
# 6                                              3395.2
# 7                                              3037.6
# 8                                               512.1
# 9                                               771.4
# 10                                              648.3
# 11                                             1217.5
# 12                                             2983.5
# 13                                              495.9
# 14                                                0.0
# 15                                             1286.0
# 16                                             1463.4
#
#     nauczyciele akademiccy;ogółem;wyższe szkoły techniczne;2016;[osoba]  \
# 1                                              2051.7
# 2                                                 0.0
# 3                                               587.7
# 4                                                 0.0
# 5                                              1368.7
# 6                                              3382.0
# 7                                              3045.2
# 8                                               505.0
# 9                                               777.8
# 10                                              643.7
# 11                                             1230.0
# 12                                             2925.3
# 13                                              498.2
# 14                                                0.0
# 15                                             1274.0
# 16                                             1412.6
#
#     nauczyciele akademiccy;ogółem;wyższe szkoły techniczne;2017;[osoba]  ...  \
# 1                                              2080.3                    ...
# 2                                                 0.0                    ...
# 3                                               581.8                    ...
# 4                                                 0.0                    ...
# 5                                              1321.8                    ...
# 6                                              3351.9                    ...
# 7                                              3033.4                    ...
# 8                                               494.2                    ...
# 9                                               856.0                    ...
# 10                                              647.0                    ...
# 11                                             1247.1                    ...
# 12                                             2816.8                    ...
# 13                                              480.1                    ...
# 14                                                0.0                    ...
# 15                                             1276.7                    ...
# 16                                             1343.0                    ...
#
#     asystenci;kobiety;uniwersytety;2014;[osoba]  \
# 1                                          28.6
# 2                                         272.0
# 3                                         283.0
# 4                                          49.0
# 5                                         134.7
# 6                                         420.6
# 7                                         147.6
# 8                                          22.5
# 9                                          97.2
# 10                                        109.2
# 11                                        102.5
# 12                                        139.0
# 13                                         48.0
# 14                                        168.0
# 15                                         10.5
# 16                                        124.5
#
#     asystenci;kobiety;uniwersytety;2015;[osoba]  \
# 1                                          46.6
# 2                                         262.7
# 3                                         265.0
# 4                                          47.5
# 5                                         133.2
# 6                                         440.2
# 7                                         174.8
# 8                                          21.0
# 9                                         114.8
# 10                                        111.2
# 11                                        109.3
# 12                                        145.7
# 13                                         45.0
# 14                                        161.0
# 15                                         13.0
# 16                                        111.0
#
#     asystenci;kobiety;uniwersytety;2016;[osoba]  \
# 1                                          58.3
# 2                                         276.8
# 3                                         269.5
# 4                                          54.5
# 5                                         133.5
# 6                                         454.7
# 7                                         206.0
# 8                                          18.0
# 9                                         127.5
# 10                                        112.0
# 11                                        107.9
# 12                                        151.0
# 13                                         44.0
# 14                                        175.9
# 15                                         13.5
# 16                                        100.5
#
#     asystenci;kobiety;uniwersytety;2017;[osoba]  \
# 1                                          66.0
# 2                                         311.2
# 3                                         243.5
# 4                                          61.0
# 5                                         130.8
# 6                                         513.9
# 7                                         229.3
# 8                                          20.6
# 9                                         139.5
# 10                                        126.0
# 11                                        123.6
# 12                                        138.5
# 13                                         47.0
# 14                                        169.2
# 15                                          8.5
# 16                                         87.0
#
#     asystenci;kobiety;uniwersytety;2018;[osoba]  \
# 1                                          65.7
# 2                                         258.8
# 3                                         230.9
# 4                                          22.0
# 5                                         121.9
# 6                                         513.1
# 7                                         229.1
# 8                                          15.1
# 9                                         115.5
# 10                                        132.0
# 11                                        124.3
# 12                                        113.8
# 13                                         61.0
# 14                                        134.8
# 15                                          5.0
# 16                                         72.3
#
#     asystenci;kobiety;wyższe szkoły techniczne;2014;[osoba]  \
# 1                                               108.8
# 2                                                 0.0
# 3                                                42.0
# 4                                                 0.0
# 5                                                41.5
# 6                                               212.3
# 7                                               112.2
# 8                                                41.6
# 9                                                56.2
# 10                                               48.8
# 11                                               48.1
# 12                                              106.3
# 13                                               61.0
# 14                                                0.0
# 15                                               90.8
# 16                                               81.0
#
#     asystenci;kobiety;wyższe szkoły techniczne;2015;[osoba]  \
# 1                                               108.5
# 2                                                 0.0
# 3                                                42.0
# 4                                                 0.0
# 5                                                42.3
# 6                                               230.7
# 7                                               108.5
# 8                                                39.1
# 9                                                54.8
# 10                                               46.5
# 11                                               51.1
# 12                                              110.1
# 13                                               74.0
# 14                                                0.0
# 15                                               97.1
# 16                                               61.5
#
#     asystenci;kobiety;wyższe szkoły techniczne;2016;[osoba]  \
# 1                                               111.5
# 2                                                 0.0
# 3                                                49.0
# 4                                                 0.0
# 5                                                31.7
# 6                                               231.0
# 7                                               115.0
# 8                                                35.0
# 9                                                57.3
# 10                                               44.0
# 11                                               61.5
# 12                                              107.1
# 13                                               69.0
# 14                                                0.0
# 15                                              101.8
# 16                                               67.3
#
#     asystenci;kobiety;wyższe szkoły techniczne;2017;[osoba]  \
# 1                                               107.3
# 2                                                 0.0
# 3                                                47.0
# 4                                                 0.0
# 5                                                29.3
# 6                                               228.6
# 7                                               115.8
# 8                                                29.0
# 9                                                72.3
# 10                                               38.5
# 11                                               69.7
# 12                                               99.1
# 13                                               68.0
# 14                                                0.0
# 15                                              106.5
# 16                                               61.5
#
#     asystenci;kobiety;wyższe szkoły techniczne;2018;[osoba]
# 1                                                99.2
# 2                                                 0.0
# 3                                                47.0
# 4                                                 0.0
# 5                                                21.8
# 6                                               192.7
# 7                                               124.6
# 8                                                23.0
# 9                                                70.3
# 10                                               26.3
# 11                                               70.9
# 12                                               93.7
# 13                                                5.0
# 14                                                0.0
# 15                                              111.2
# 16                                               51.3
#
# [16 rows x 101 columns]

# %% [markdown]
# # Task 3.1.

# %% [markdown]
# **Extracting Informations for academic teachers**

# %%
colleage_teachers: pd.DataFrame = df.filter(regex='nauczyciele akademiccy|Nazwa', axis=1)

# %% [markdown]
# **Ploting extracted data using plotly**

# %%
propper_cols: list[str] = list([col for col in list(colleage_teachers.columns) if 'nauczyciele' in col])
# Creating summary for propper data handling
summary: pd.DataFrame = colleage_teachers.melt(id_vars=['Nazwa'], value_vars=propper_cols, var_name='Year', value_name='Teachers Amount')

# ploting data using plotly.express
fig = px.bar(summary, x='Nazwa', y='Teachers Amount', color='Year', barmode='group', title='Summary of academic staff 2014-2018')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="cabf4a53-18a3-4fff-9aac-dc920c9ff72b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cabf4a53-18a3-4fff-9aac-dc920c9ff72b")) {                    Plotly.newPlot(                        "cabf4a53-18a3-4fff-9aac-dc920c9ff72b",                        [{"alignmentgroup":"True","hovertemplate":"Year=nauczyciele akademiccy;og\u00f3\u0142em;uniwersytety;2014;[osoba]<br>Nazwa=%{x}<br>Teachers Amount=%{y}<extra></extra>","legendgroup":"nauczyciele akademiccy;og\u00f3\u0142em;uniwersytety;2014;[osoba]","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"nauczyciele akademiccy;og\u00f3\u0142em;uniwersytety;2014;[osoba]","offsetgroup":"nauczyciele akademiccy;og\u00f3\u0142em;uniwersytety;2014;[osoba]","orientation":"v","showlegend":true,"textposition":"auto","x":["DOLNO\u015aL\u0104SKIE","KUJAWSKO-POMORSKIE","LUBELSKIE","LUBUSKIE","\u0141\u00d3DZKIE","MA\u0141OPOLSKIE","MAZOWIECKIE","OPOLSKIE","PODKARPACKIE","PODLASKIE","POMORSKIE","\u015aL\u0104SKIE","\u015aWI\u0118TOKRZYSKIE","WARMI\u0143SKO-MAZURSKIE","WIELKOPOLSKIE","ZACHODNIOPOMORSKIE"],"xaxis":"x","y":[1837.7,2689.9,2912.0,899.0,2188.2,3879.4,4196.0,696.4,1275.8,776.1,1670.6,1940.9,856.0,1994.0,2963.9,1152.2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Year=nauczyciele akademiccy;og\u00f3\u0142em;uniwersytety;2015;[osoba]<br>Nazwa=%{x}<br>Teachers Amount=%{y}<extra></extra>","legendgroup":"nauczyciele akademiccy;og\u00f3\u0142em;uniwersytety;2015;[osoba]","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"nauczyciele akademiccy;og\u00f3\u0142em;uniwersytety;2015;[osoba]","offsetgroup":"nauczyciele akademiccy;og\u00f3\u0142em;uniwersytety;2015;[osoba]","orientation":"v","showlegend":true,"textposition":"auto","x":["DOLNO\u015aL\u0104SKIE","KUJAWSKO-POMORSKIE","LUBELSKIE","LUBUSKIE","\u0141\u00d3DZKIE","MA\u0141OPOLSKIE","MAZOWIECKIE","OPOLSKIE","PODKARPACKIE","PODLASKIE","POMORSKIE","\u015aL\u0104SKIE","\u015aWI\u0118TOKRZYSKIE","WARMI\u0143SKO-MAZURSKIE","WIELKOPOLSKIE","ZACHODNIOPOMORSKIE"],"xaxis":"x","y":[1856.7,2651.1,2770.8,884.5,2159.2,3932.9,4259.0,688.7,1290.1,753.8,1700.5,1941.2,850.4,1924.1,2918.3,1118.9],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Year=nauczyciele akademiccy;og\u00f3\u0142em;uniwersytety;2016;[osoba]<br>Nazwa=%{x}<br>Teachers Amount=%{y}<extra></extra>","legendgroup":"nauczyciele akademiccy;og\u00f3\u0142em;uniwersytety;2016;[osoba]","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"nauczyciele akademiccy;og\u00f3\u0142em;uniwersytety;2016;[osoba]","offsetgroup":"nauczyciele akademiccy;og\u00f3\u0142em;uniwersytety;2016;[osoba]","orientation":"v","showlegend":true,"textposition":"auto","x":["DOLNO\u015aL\u0104SKIE","KUJAWSKO-POMORSKIE","LUBELSKIE","LUBUSKIE","\u0141\u00d3DZKIE","MA\u0141OPOLSKIE","MAZOWIECKIE","OPOLSKIE","PODKARPACKIE","PODLASKIE","POMORSKIE","\u015aL\u0104SKIE","\u015aWI\u0118TOKRZYSKIE","WARMI\u0143SKO-MAZURSKIE","WIELKOPOLSKIE","ZACHODNIOPOMORSKIE"],"xaxis":"x","y":[1884.5,2647.4,2721.5,920.0,2145.6,4022.4,4303.5,678.0,1306.6,747.7,1685.8,1950.4,872.4,1908.2,2929.8,1114.7],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Year=nauczyciele akademiccy;og\u00f3\u0142em;uniwersytety;2017;[osoba]<br>Nazwa=%{x}<br>Teachers Amount=%{y}<extra></extra>","legendgroup":"nauczyciele akademiccy;og\u00f3\u0142em;uniwersytety;2017;[osoba]","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"nauczyciele akademiccy;og\u00f3\u0142em;uniwersytety;2017;[osoba]","offsetgroup":"nauczyciele akademiccy;og\u00f3\u0142em;uniwersytety;2017;[osoba]","orientation":"v","showlegend":true,"textposition":"auto","x":["DOLNO\u015aL\u0104SKIE","KUJAWSKO-POMORSKIE","LUBELSKIE","L ...

# %% [markdown]
# # Task 3.2.

# %% [markdown]
# **Extracting data for:**
# 1. Assistants,
# 2. Adjuncts,
# 3. Professors\
# employed in 2014-2018 in the province of Silesia.

# %%
def plot_transposed_df(df: pd.DataFrame, title: str) -> None:
  """
  Function that multiplies passed amount of values and return its result.

  Args:
        df (__pd.DataFrame__): DataFrame object to plot.
        title (__str__): Graph title.
        
  Raises:
        TypeError: Occures when provided dataframe is not correct.
  """
  if df.empty:
    raise TypeError('Provided dataframe is empty!')

  # Formatting data to plotly format
  df_transposed: pd.DataFrame = df.transpose()
  df_transposed.columns = ['Values']

  # Creating plotly graph object
  fig = px.bar(df_transposed, x=df_transposed.index, y='Values', title=title)
  fig.show()

# %%
# Cleaning and selecting propper data
silesia_academics: pd.DataFrame = df.filter(regex='Nazwa|adiunkci|profesorowie|asystenci', axis=1)
silesia_academics = silesia_academics[silesia_academics['Nazwa'] == 'ŚLĄSKIE']

# %% [markdown]
# **Summary of 3.2. using px**

# %%
plot_transposed_df(silesia_academics, "Summary of various positions (assistants, assistant professors, professors) employed in 2014-2018 in the province of Silesia")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="6661fce8-3c91-425c-b5a6-9b1634fdf6e5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6661fce8-3c91-425c-b5a6-9b1634fdf6e5")) {                    Plotly.newPlot(                        "6661fce8-3c91-425c-b5a6-9b1634fdf6e5",                        [{"alignmentgroup":"True","hovertemplate":"index=%{x}<br>Values=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Nazwa","profesorowie;og\u00f3\u0142em;uniwersytety;2014;[osoba]","profesorowie;og\u00f3\u0142em;uniwersytety;2015;[osoba]","profesorowie;og\u00f3\u0142em;uniwersytety;2016;[osoba]","profesorowie;og\u00f3\u0142em;uniwersytety;2017;[osoba]","profesorowie;og\u00f3\u0142em;uniwersytety;2018;[osoba]","profesorowie;og\u00f3\u0142em;wy\u017csze szko\u0142y techniczne;2014;[osoba]","profesorowie;og\u00f3\u0142em;wy\u017csze szko\u0142y techniczne;2015;[osoba]","profesorowie;og\u00f3\u0142em;wy\u017csze szko\u0142y techniczne;2016;[osoba]","profesorowie;og\u00f3\u0142em;wy\u017csze szko\u0142y techniczne;2017;[osoba]","profesorowie;og\u00f3\u0142em;wy\u017csze szko\u0142y techniczne;2018;[osoba]","profesorowie;kobiety;uniwersytety;2014;[osoba]","profesorowie;kobiety;uniwersytety;2015;[osoba]","profesorowie;kobiety;uniwersytety;2016;[osoba]","profesorowie;kobiety;uniwersytety;2017;[osoba]","profesorowie;kobiety;uniwersytety;2018;[osoba]","profesorowie;kobiety;wy\u017csze szko\u0142y techniczne;2014;[osoba]","profesorowie;kobiety;wy\u017csze szko\u0142y techniczne;2015;[osoba]","profesorowie;kobiety;wy\u017csze szko\u0142y techniczne;2016;[osoba]","profesorowie;kobiety;wy\u017csze szko\u0142y techniczne;2017;[osoba]","profesorowie;kobiety;wy\u017csze szko\u0142y techniczne;2018;[osoba]","adiunkci;og\u00f3\u0142em;uniwersytety;2014;[osoba]","adiunkci;og\u00f3\u0142em;uniwersytety;2015;[osoba]","adiunkci;og\u00f3\u0142em;uniwersytety;2016;[osoba]","adiunkci;og\u00f3\u0142em;uniwersytety;2017;[osoba]","adiunkci;og\u00f3\u0142em;uniwersytety;2018;[osoba]","adiunkci;og\u00f3\u0142em;wy\u017csze szko\u0142y techniczne;2014;[osoba]","adiunkci;og\u00f3\u0142em;wy\u017csze szko\u0142y techniczne;2015;[osoba]","adiunkci;og\u00f3\u0142em;wy\u017csze szko\u0142y techniczne;2016;[osoba]","adiunkci;og\u00f3\u0142em;wy\u017csze szko\u0142y techniczne;2017;[osoba]","adiunkci;og\u00f3\u0142em;wy\u017csze szko\u0142y techniczne;2018;[osoba]","adiunkci;kobiety;uniwersytety;2014;[osoba]","adiunkci;kobiety;uniwersytety;2015;[osoba]","adiunkci;kobiety;uniwersytety;2016;[osoba]","adiunkci;kobiety;uniwersytety;2017;[osoba]","adiunkci;kobiety;uniwersytety;2018;[osoba]","adiunkci;kobiety;wy\u017csze szko\u0142y techniczne;2014;[osoba]","adiunkci;kobiety;wy\u017csze szko\u0142y techniczne;2015;[osoba]","adiunkci;kobiety;wy\u017csze szko\u0142y techniczne;2016;[osoba]","adiunkci;kobiety;wy\u017csze szko\u0142y techniczne;2017;[osoba]","adiunkci;kobiety;wy\u017csze szko\u0142y techniczne;2018;[osoba]","asystenci;og\u00f3\u0142em;uniwersytety;2014;[osoba]","asystenci;og\u00f3\u0142em;uniwersytety;2015;[osoba]","asystenci;og\u00f3\u0142em;uniwersytety;2016;[osoba]","asystenci;og\u00f3\u0142em;uniwersytety;2017;[osoba]","asystenci;og\u00f3\u0142em;uniwersytety;2018;[osoba]","asystenci;og\u00f3\u0142em;wy\u017csze szko\u0142y techniczne;2014;[osoba]","asystenci;og\u00f3\u0142em;wy\u017csze szko\u0142y techniczne;2015;[osoba]","asystenci;og\u00f3\u0142em;wy\u017csze szko\u0142y techniczne;2016;[osoba]","asystenci;og\u00f3\u0142em;wy\u017csze szko\u0142y techniczne;2017;[osoba]","asystenci;og\u00f3\u0142em;wy\u017csze szko\u0142y techniczne;2018;[osoba]","asystenci;kobiety;uniwersytety;2014;[os ...

# %% [markdown]
# # Task 3.3.

# %% [markdown]
# **Extracting data for task:**\
# summary of academic teachers employed at universities and technical schools by gender
# in Śląskie voivodship

# %%
# Cleaning and selecting propper data
silesia_gender: pd.DataFrame = df.filter(regex='Nazwa|uniwersytety|szkoły techniczne', axis=1)
silesia_gender = df.filter(regex='Nazwa|nauczyciele', axis=1)
silesia_gender = silesia_gender[silesia_gender['Nazwa'] == 'ŚLĄSKIE']

# %% [markdown]
# **Plotting data using px**

# %%
plot_transposed_df(silesia_gender, "Summary of academic teachers employed at universities and technical schools by genderin Silesia voivodship")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="8f1c8d4b-6f9e-47af-bd9a-8c9ac6dbb44f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8f1c8d4b-6f9e-47af-bd9a-8c9ac6dbb44f")) {                    Plotly.newPlot(                        "8f1c8d4b-6f9e-47af-bd9a-8c9ac6dbb44f",                        [{"alignmentgroup":"True","hovertemplate":"index=%{x}<br>Values=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Nazwa","nauczyciele akademiccy;og\u00f3\u0142em;uniwersytety;2014;[osoba]","nauczyciele akademiccy;og\u00f3\u0142em;uniwersytety;2015;[osoba]","nauczyciele akademiccy;og\u00f3\u0142em;uniwersytety;2016;[osoba]","nauczyciele akademiccy;og\u00f3\u0142em;uniwersytety;2017;[osoba]","nauczyciele akademiccy;og\u00f3\u0142em;uniwersytety;2018;[osoba]","nauczyciele akademiccy;og\u00f3\u0142em;wy\u017csze szko\u0142y techniczne;2014;[osoba]","nauczyciele akademiccy;og\u00f3\u0142em;wy\u017csze szko\u0142y techniczne;2015;[osoba]","nauczyciele akademiccy;og\u00f3\u0142em;wy\u017csze szko\u0142y techniczne;2016;[osoba]","nauczyciele akademiccy;og\u00f3\u0142em;wy\u017csze szko\u0142y techniczne;2017;[osoba]","nauczyciele akademiccy;og\u00f3\u0142em;wy\u017csze szko\u0142y techniczne;2018;[osoba]","nauczyciele akademiccy;kobiety;uniwersytety;2014;[osoba]","nauczyciele akademiccy;kobiety;uniwersytety;2015;[osoba]","nauczyciele akademiccy;kobiety;uniwersytety;2016;[osoba]","nauczyciele akademiccy;kobiety;uniwersytety;2017;[osoba]","nauczyciele akademiccy;kobiety;uniwersytety;2018;[osoba]","nauczyciele akademiccy;kobiety;wy\u017csze szko\u0142y techniczne;2014;[osoba]","nauczyciele akademiccy;kobiety;wy\u017csze szko\u0142y techniczne;2015;[osoba]","nauczyciele akademiccy;kobiety;wy\u017csze szko\u0142y techniczne;2016;[osoba]","nauczyciele akademiccy;kobiety;wy\u017csze szko\u0142y techniczne;2017;[osoba]","nauczyciele akademiccy;kobiety;wy\u017csze szko\u0142y techniczne;2018;[osoba]"],"xaxis":"x","y":["\u015aL\u0104SKIE",1940.9,1941.2,1950.4,1930.2,1887.7,3040.3,2983.5,2925.3,2816.8,2731.9,1088.8,1084.1,1105.5,1084.2,1061.2,1057.3,1040.1,1049.5,1024.4,1030.7],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"# ...

# %% [markdown]
# # Task 4.

# %% [markdown]
# **Task 4.1.** Values for Silesia voivodship

# %%
silesia_df: pd.DataFrame = df[df['Nazwa'] == 'ŚLĄSKIE']
silesia_df
# Out:
#       Nazwa  nauczyciele akademiccy;ogółem;uniwersytety;2014;[osoba]  \
# 12  ŚLĄSKIE                                             1940.9
#
#     nauczyciele akademiccy;ogółem;uniwersytety;2015;[osoba]  \
# 12                                             1941.2
#
#     nauczyciele akademiccy;ogółem;uniwersytety;2016;[osoba]  \
# 12                                             1950.4
#
#     nauczyciele akademiccy;ogółem;uniwersytety;2017;[osoba]  \
# 12                                             1930.2
#
#     nauczyciele akademiccy;ogółem;uniwersytety;2018;[osoba]  \
# 12                                             1887.7
#
#     nauczyciele akademiccy;ogółem;wyższe szkoły techniczne;2014;[osoba]  \
# 12                                             3040.3
#
#     nauczyciele akademiccy;ogółem;wyższe szkoły techniczne;2015;[osoba]  \
# 12                                             2983.5
#
#     nauczyciele akademiccy;ogółem;wyższe szkoły techniczne;2016;[osoba]  \
# 12                                             2925.3
#
#     nauczyciele akademiccy;ogółem;wyższe szkoły techniczne;2017;[osoba]  ...  \
# 12                                             2816.8                    ...
#
#     asystenci;kobiety;uniwersytety;2014;[osoba]  \
# 12                                        139.0
#
#     asystenci;kobiety;uniwersytety;2015;[osoba]  \
# 12                                        145.7
#
#     asystenci;kobiety;uniwersytety;2016;[osoba]  \
# 12                                        151.0
#
#     asystenci;kobiety;uniwersytety;2017;[osoba]  \
# 12                                        138.5
#
#     asystenci;kobiety;uniwersytety;2018;[osoba]  \
# 12                                        113.8
#
#     asystenci;kobiety;wyższe szkoły techniczne;2014;[osoba]  \
# 12                                              106.3
#
#     asystenci;kobiety;wyższe szkoły techniczne;2015;[osoba]  \
# 12                                              110.1
#
#     asystenci;kobiety;wyższe szkoły techniczne;2016;[osoba]  \
# 12                                              107.1
#
#     asystenci;kobiety;wyższe szkoły techniczne;2017;[osoba]  \
# 12                                               99.1
#
#     asystenci;kobiety;wyższe szkoły techniczne;2018;[osoba]
# 12                                               93.7
#
# [1 rows x 101 columns]

# %% [markdown]
# **Task 4.2.** Provinces with the most and the least number of university teachers employed

# %%
# Decided to count teachers for the latest data - 2018 year
# Searching though data frame
academic_df: pd.DataFrame = df.filter(regex='Nazwa|akademiccy', axis=1)
academic_df = academic_df.filter(regex='Nazwa|2018', axis=1)
# Creating sum
academic_df['Teachers Amount'] = academic_df.select_dtypes(include='number').sum(axis=1)

# %%
# Min values of teachers
min_teachers_amount: pd.DataFrame = academic_df.nsmallest(1, 'Teachers Amount')
min_teachers_amount
# Out:
#       Nazwa  nauczyciele akademiccy;ogółem;uniwersytety;2018;[osoba]  \
# 4  LUBUSKIE                                              982.5
#
#    nauczyciele akademiccy;ogółem;wyższe szkoły techniczne;2018;[osoba]  \
# 4                                                0.0
#
#    nauczyciele akademiccy;kobiety;uniwersytety;2018;[osoba]  \
# 4                                              431.5
#
#    nauczyciele akademiccy;kobiety;wyższe szkoły techniczne;2018;[osoba]  \
# 4                                                0.0
#
#    Teachers Amount
# 4           1414.0

# %%
# Max values of teachers
max_teachers_amount: pd.DataFrame = academic_df.nlargest(1, 'Teachers Amount')
max_teachers_amount
# Out:
#          Nazwa  nauczyciele akademiccy;ogółem;uniwersytety;2018;[osoba]  \
# 6  MAŁOPOLSKIE                                             4120.7
#
#    nauczyciele akademiccy;ogółem;wyższe szkoły techniczne;2018;[osoba]  \
# 6                                             3246.4
#
#    nauczyciele akademiccy;kobiety;uniwersytety;2018;[osoba]  \
# 6                                             2113.0
#
#    nauczyciele akademiccy;kobiety;wyższe szkoły techniczne;2018;[osoba]  \
# 6                                             1043.8
#
#    Teachers Amount
# 6          10523.9

# %% [markdown]
# **Task 2**
# 1. load the file inflation.xlsx, which contains data on the level of inflation in Poland (subsequent binders).
# 2. Prepare the data for further analysis (remove unnecessary rows and columns, pay attention to the type of data).
# 3. create the following charts:
# - summary of 2017, 2018 and 2019 in relation to December of the previous year (Table 1)
# - summary of October of 2017, 2018 and 2019 with respect to the previous month of the year (Table 2)
# - summary of 2017, 2018 and 2019 in relation to the corresponding month of the previous year (Table 3)
# 4. In the data, find:
# - the largest and smallest values in each category
# - determine the highest values of inflation in each year
# - determine the average value of inflation in each year

# %% [markdown]
# # Task 1 and 2

# %%
INFLATION_DATA_PATH: Final[str] = r'/content/inflacja.xlsx'
excel_file = pd.ExcelFile(INFLATION_DATA_PATH)

# %%
def format_inflation(header: int, sheet_name: str, drop_bottom_rows: int) -> pd.DataFrame:
  """
  Function that formats 1st type of inflation to propper dataframe.

  Args:
        header (__int__): Integer amount of header rows.
        sheet_name (__str__): String representation of sheet name.
        drop_bottom_rows (__int__): Amount of rows to cut.
  Returns:
      pd.DataFrame: Propperly formatted inflation of 1st type.
  """
  df: pd.DataFrame = pd.read_excel(excel_file, sheet_name = sheet_name, header=header)
  df = df.drop(columns= ['Unnamed: 0', 'Unnamed: 1'])
  df = df.rename(columns = dict({
    'Unnamed: 2': 'Year',
    'I': 'January',
    'II': 'February',
    'III': 'March',
    'IV': 'April',
    'V': 'May',
    'VI': 'June',
    'VII': 'July',
    'VIII': 'August',
    'IX': 'September',
    'X': 'October',
    'XI': 'November',
    'XII': 'December'
  }))
  df = df.iloc[:-drop_bottom_rows, :]
  df = df.replace('1999a', '1999')
  return df

def melt_inflation(inflation_df: pd.DataFrame) -> pd.DataFrame:
  """
  Function  to melt inflation to propper plotly express format, formatting year and month columns as date.

  Args:
    inflation_df (__pd.DataFrame__): DataFrame of inflation data.

  Returns: 
    pd.DataFrame: Melted dataframe.
  """
  inflation_df = pd.melt(inflation_df, id_vars=['Year'], var_name='Month', value_name='Value')
  inflation_df['Data'] = pd.to_datetime(inflation_df['Year'].astype(str) + '-' + inflation_df['Month'], format='%Y-%B')
  return inflation_df

# %%
inflation_df: pd.DataFrame = format_inflation(6, 'Table 1', 2)
inflation_df = melt_inflation(inflation_df)
inflation_df
# Out:
#      Year     Month  Value       Data
# 0    2019   January   99.8 2019-01-01
# 1    2018   January  100.3 2018-01-01
# 2    2017   January  100.4 2017-01-01
# 3    2016   January   99.5 2016-01-01
# 4    2015   January   99.8 2015-01-01
# ..    ...       ...    ...        ...
# 391  1991  December  160.4 1991-12-01
# 392  1990  December  349.3 1990-12-01
# 393  1989  December  739.6 1989-12-01
# 394  1988  December  173.9 1988-12-01
# 395  1987  December  131.3 1987-12-01
#
# [396 rows x 4 columns]

# %% [markdown]
# # Task 3

# %% [markdown]
# **Task 3.1.** Summary of 2017, 2018 and 2019 in relation to december of the previous year

# %%
def plot_summary_inflation(df: pd.DataFrame, title: str) -> None:
    """
    Function to create graph summary for inflation data.
    Args:
      df (__pd.DataFrame__): DataFrame melted object.
      title (__str__): String representation of graph title.
    """
    if not df.empty:
      df["Month"] = pd.to_datetime(df["Data"]).dt.month
      fig = px.line(df, x="Data", y="Value", color="Month", title=title)
      fig.show()
    else:
      raise TypeError('Invalid dataframe format!')

# %%
filtered_inflation_df: pd.DataFrame = inflation_df[inflation_df['Data'] >= '2017-01-01']
filtered_inflation_df = filtered_inflation_df.iloc[:, 2:]

# %%
plot_summary_inflation(filtered_inflation_df, "Summary of 2017, 2018 and 2019 in relation to december of the previous year")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="365abe13-c4b7-4925-a5f6-aa65a51f1d93" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("365abe13-c4b7-4925-a5f6-aa65a51f1d93")) {                    Plotly.newPlot(                        "365abe13-c4b7-4925-a5f6-aa65a51f1d93",                        [{"hovertemplate":"Month=1<br>Data=%{x}<br>Value=%{y}<extra></extra>","legendgroup":"1","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"1","orientation":"v","showlegend":true,"x":["2019-01-01T00:00:00","2018-01-01T00:00:00","2017-01-01T00:00:00"],"xaxis":"x","y":[99.8,100.3,100.4],"yaxis":"y","type":"scatter"},{"hovertemplate":"Month=2<br>Data=%{x}<br>Value=%{y}<extra></extra>","legendgroup":"2","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"2","orientation":"v","showlegend":true,"x":["2019-02-01T00:00:00","2018-02-01T00:00:00","2017-02-01T00:00:00"],"xaxis":"x","y":[100.2,100.1,100.7],"yaxis":"y","type":"scatter"},{"hovertemplate":"Month=3<br>Data=%{x}<br>Value=%{y}<extra></extra>","legendgroup":"3","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"3","orientation":"v","showlegend":true,"x":["2019-03-01T00:00:00","2018-03-01T00:00:00","2017-03-01T00:00:00"],"xaxis":"x","y":[100.5,100.0,100.7],"yaxis":"y","type":"scatter"},{"hovertemplate":"Month=4<br>Data=%{x}<br>Value=%{y}<extra></extra>","legendgroup":"4","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"4","orientation":"v","showlegend":true,"x":["2019-04-01T00:00:00","2018-04-01T00:00:00","2017-04-01T00:00:00"],"xaxis":"x","y":[101.6,100.5,100.9],"yaxis":"y","type":"scatter"},{"hovertemplate":"Month=5<br>Data=%{x}<br>Value=%{y}<extra></extra>","legendgroup":"5","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"5","orientation":"v","showlegend":true,"x":["2019-05-01T00:00:00","2018-05-01T00:00:00","2017-05-01T00:00:00"],"xaxis":"x","y":[101.9,100.6,101.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Month=6<br>Data=%{x}<br>Value=%{y}<extra></extra>","legendgroup":"6","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"6","orientation":"v","showlegend":true,"x":["2019-06-01T00:00:00","2018-06-01T00:00:00","2017-06-01T00:00:00"],"xaxis":"x","y":[102.2,100.7,100.8],"yaxis":"y","type":"scatter"},{"hovertemplate":"Month=7<br>Data=%{x}<br>Value=%{y}<extra></extra>","legendgroup":"7","line":{"color":"#FF6692","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"7","orientation":"v","showlegend":true,"x":["2019-07-01T00:00:00","2018-07-01T00:00:00","2017-07-01T00:00:00"],"xaxis":"x","y":[102.2,100.6,100.6],"yaxis":"y","type":"scatter"},{"hovertemplate":"Month=8<br>Data=%{x}<br>Value=%{y}<extra></extra>","legendgroup":"8","line":{"color":"#B6E880","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"8","orientation":"v","showlegend":true,"x":["2019-08-01T00:00:00","2018-08-01T00:00:00","2017-08-01T00:00:00"],"xaxis":"x","y":[102.2,100.5,100.5],"yaxis":"y","type":"scatter"},{"hovertemplate":"Month=9<br>Data=%{x}<br>Value=%{y}<extra></extra>","legendgroup":"9","line":{"color":"#FF97FF","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"9","orientation":"v","showlegend":true,"x":["2019-09-01T00:00:00","2018-09-01T00:00:00","2017-09-01T00:00:00"],"xaxis":"x","y":[102.2,100.7,100.9],"yaxis":"y","type":"scatter"},{"hovertemplate":"Month=10<br>Data=%{x}<br>Value=%{y}<extra></extra>","legendgroup":"10","line":{"color":"#FECB52","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"10","orientation":"v","showlegend":true,"x":["20 ...

# %% [markdown]
# **Task 3.2.**

# %% [markdown]
# **Data prep**

# %%
def prep_inflation_v2(sheet_name: str, to_drop_text: str, drop_rows:int) -> pd.DataFrame:
  """
  Function that formats 2nd type of inflation to propper dataframe.

  Args:
        drop_rows (__int__): Integer amount of header rows.
        sheet_name (__str__): String representation of sheet name.
        drop_rows (__int__): Amount of rows to cut.
  Retruns:
        pd.DataFrame: Propperly formatted inflation of 2nd type.
  """
  df: pd.DataFrame = pd.read_excel(excel_file, sheet_name=sheet_name)
  df = df.drop(columns = [to_drop_text])
  df.columns = list(['Year', 'January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December'])
  df = df.replace('1999a', '1999')
  df = df.iloc[:-drop_rows, :]
  return df

# %%
previous_month_inflation = prep_inflation_v2('Table 2', 'Analogiczny miesiąc poprzedniego roku = 100', 2)
previous_month_inflation_melted= melt_inflation(previous_month_inflation)
previous_month_inflation_melted: pd.DataFrame = previous_month_inflation_melted[previous_month_inflation_melted['Data'] >= '2017-01-01']
previous_month_inflation_melted = previous_month_inflation_melted.iloc[:, 2:]

# %%
plot_summary_inflation(previous_month_inflation_melted, "Summary of 2017, 2018 and 2019 with respect to the previous month of the year")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="b2f11348-b249-4023-8e42-087562c1b4cf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b2f11348-b249-4023-8e42-087562c1b4cf")) {                    Plotly.newPlot(                        "b2f11348-b249-4023-8e42-087562c1b4cf",                        [{"hovertemplate":"Month=1<br>Data=%{x}<br>Value=%{y}<extra></extra>","legendgroup":"1","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"1","orientation":"v","showlegend":true,"x":["2018-01-01T00:00:00","2017-01-01T00:00:00"],"xaxis":"x","y":[101.9,101.7],"yaxis":"y","type":"scatter"},{"hovertemplate":"Month=2<br>Data=%{x}<br>Value=%{y}<extra></extra>","legendgroup":"2","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"2","orientation":"v","showlegend":true,"x":["2018-02-01T00:00:00","2017-02-01T00:00:00"],"xaxis":"x","y":[101.4,102.2],"yaxis":"y","type":"scatter"},{"hovertemplate":"Month=3<br>Data=%{x}<br>Value=%{y}<extra></extra>","legendgroup":"3","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"3","orientation":"v","showlegend":true,"x":["2018-03-01T00:00:00","2017-03-01T00:00:00"],"xaxis":"x","y":[101.3,102],"yaxis":"y","type":"scatter"},{"hovertemplate":"Month=4<br>Data=%{x}<br>Value=%{y}<extra></extra>","legendgroup":"4","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"4","orientation":"v","showlegend":true,"x":["2018-04-01T00:00:00","2017-04-01T00:00:00"],"xaxis":"x","y":[101.6,102],"yaxis":"y","type":"scatter"},{"hovertemplate":"Month=5<br>Data=%{x}<br>Value=%{y}<extra></extra>","legendgroup":"5","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"5","orientation":"v","showlegend":true,"x":["2018-05-01T00:00:00","2017-05-01T00:00:00"],"xaxis":"x","y":[101.7,101.9],"yaxis":"y","type":"scatter"},{"hovertemplate":"Month=6<br>Data=%{x}<br>Value=%{y}<extra></extra>","legendgroup":"6","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"6","orientation":"v","showlegend":true,"x":["2018-06-01T00:00:00","2017-06-01T00:00:00"],"xaxis":"x","y":[102,101.5],"yaxis":"y","type":"scatter"},{"hovertemplate":"Month=7<br>Data=%{x}<br>Value=%{y}<extra></extra>","legendgroup":"7","line":{"color":"#FF6692","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"7","orientation":"v","showlegend":true,"x":["2018-07-01T00:00:00","2017-07-01T00:00:00"],"xaxis":"x","y":[102,101.7],"yaxis":"y","type":"scatter"},{"hovertemplate":"Month=8<br>Data=%{x}<br>Value=%{y}<extra></extra>","legendgroup":"8","line":{"color":"#B6E880","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"8","orientation":"v","showlegend":true,"x":["2018-08-01T00:00:00","2017-08-01T00:00:00"],"xaxis":"x","y":[102,101.8],"yaxis":"y","type":"scatter"},{"hovertemplate":"Month=9<br>Data=%{x}<br>Value=%{y}<extra></extra>","legendgroup":"9","line":{"color":"#FF97FF","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"9","orientation":"v","showlegend":true,"x":["2018-09-01T00:00:00","2017-09-01T00:00:00"],"xaxis":"x","y":[101.9,102.2],"yaxis":"y","type":"scatter"},{"hovertemplate":"Month=10<br>Data=%{x}<br>Value=%{y}<extra></extra>","legendgroup":"10","line":{"color":"#FECB52","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"10","orientation":"v","showlegend":true,"x":["2018-10-01T00:00:00","2017-10-01T00:00:00"],"xaxis":"x","y":[101.8,102.1],"yaxis":"y","type":"scatter"},{"hovertemplate":"Month=11<br>Data=%{x}<br>Value=%{y}<extra></extra>","legendgroup":"11","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"} ...

# %% [markdown]
# **Task 3.3.**

# %%
same_month_previouse_year: pd.DataFrame = prep_inflation_v2('Table 3', 'Analogiczny okres narastający poprzedniego roku = 100', 9)
same_month_previouse_year= melt_inflation(same_month_previouse_year)
same_month_previouse_year_melted: pd.DataFrame = same_month_previouse_year[same_month_previouse_year['Data'] >= '2017-01-01']
same_month_previouse_year_melted = same_month_previouse_year_melted.iloc[:, 2:]

# %%
plot_summary_inflation(same_month_previouse_year_melted, "Summary of 2017, 2018 and 2019 in relation to the corresponding month of the previous year")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="770498f6-2c97-4f87-b80b-b06b56f112ab" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("770498f6-2c97-4f87-b80b-b06b56f112ab")) {                    Plotly.newPlot(                        "770498f6-2c97-4f87-b80b-b06b56f112ab",                        [{"hovertemplate":"Month=1<br>Data=%{x}<br>Value=%{y}<extra></extra>","legendgroup":"1","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"1","orientation":"v","showlegend":true,"x":["2018-01-01T00:00:00","2017-01-01T00:00:00"],"xaxis":"x","y":[101.9,101.7],"yaxis":"y","type":"scatter"},{"hovertemplate":"Month=2<br>Data=%{x}<br>Value=%{y}<extra></extra>","legendgroup":"2","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"2","orientation":"v","showlegend":true,"x":["2018-02-01T00:00:00","2017-02-01T00:00:00"],"xaxis":"x","y":[101.6,102],"yaxis":"y","type":"scatter"},{"hovertemplate":"Month=3<br>Data=%{x}<br>Value=%{y}<extra></extra>","legendgroup":"3","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"3","orientation":"v","showlegend":true,"x":["2018-03-01T00:00:00","2017-03-01T00:00:00"],"xaxis":"x","y":[101.5,102],"yaxis":"y","type":"scatter"},{"hovertemplate":"Month=4<br>Data=%{x}<br>Value=%{y}<extra></extra>","legendgroup":"4","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"4","orientation":"v","showlegend":true,"x":["2018-04-01T00:00:00","2017-04-01T00:00:00"],"xaxis":"x","y":[101.5,102],"yaxis":"y","type":"scatter"},{"hovertemplate":"Month=5<br>Data=%{x}<br>Value=%{y}<extra></extra>","legendgroup":"5","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"5","orientation":"v","showlegend":true,"x":["2018-05-01T00:00:00","2017-05-01T00:00:00"],"xaxis":"x","y":[101.6,102],"yaxis":"y","type":"scatter"},{"hovertemplate":"Month=6<br>Data=%{x}<br>Value=%{y}<extra></extra>","legendgroup":"6","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"6","orientation":"v","showlegend":true,"x":["2018-06-01T00:00:00","2017-06-01T00:00:00"],"xaxis":"x","y":[101.6,101.9],"yaxis":"y","type":"scatter"},{"hovertemplate":"Month=7<br>Data=%{x}<br>Value=%{y}<extra></extra>","legendgroup":"7","line":{"color":"#FF6692","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"7","orientation":"v","showlegend":true,"x":["2018-07-01T00:00:00","2017-07-01T00:00:00"],"xaxis":"x","y":[101.7,101.9],"yaxis":"y","type":"scatter"},{"hovertemplate":"Month=8<br>Data=%{x}<br>Value=%{y}<extra></extra>","legendgroup":"8","line":{"color":"#B6E880","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"8","orientation":"v","showlegend":true,"x":["2018-08-01T00:00:00","2017-08-01T00:00:00"],"xaxis":"x","y":[101.7,101.9],"yaxis":"y","type":"scatter"},{"hovertemplate":"Month=9<br>Data=%{x}<br>Value=%{y}<extra></extra>","legendgroup":"9","line":{"color":"#FF97FF","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"9","orientation":"v","showlegend":true,"x":["2018-09-01T00:00:00","2017-09-01T00:00:00"],"xaxis":"x","y":[101.7,101.9],"yaxis":"y","type":"scatter"},{"hovertemplate":"Month=10<br>Data=%{x}<br>Value=%{y}<extra></extra>","legendgroup":"10","line":{"color":"#FECB52","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"10","orientation":"v","showlegend":true,"x":["2018-10-01T00:00:00","2017-10-01T00:00:00"],"xaxis":"x","y":[101.7,101.9],"yaxis":"y","type":"scatter"},{"hovertemplate":"Month=11<br>Data=%{x}<br>Value=%{y}<extra></extra>","legendgroup":"11","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle ...

# %% [markdown]
# # Task 4

# %% [markdown]
# **Task 4.1.** Find largest and smallest value for each category.

# %%
def find_max_min_inflation_value(df: pd.DataFrame, category: str) -> None:
  min_row: pd.Series = df.nsmallest(1, 'Value')
  max_row: pd.Series = df.nlargest(1, 'Value')
  print(f'MIN VALUE FOR CATEGORY: {category}')
  print(min_row)
  print(f'MAX VALUE FOR CATEGORY: {category}')
  print(max_row)
  print('\n')

# %%
# Table 1 type
type_one_inflation: pd.DataFrame = format_inflation(6, 'Table 1', 2)
type_one_inflation = melt_inflation(type_one_inflation)
find_max_min_inflation_value(type_one_inflation, 'December of previous year')
# Table 2 type
type_two_inflation = prep_inflation_v2('Table 2', 'Analogiczny miesiąc poprzedniego roku = 100', 2)
type_two_inflation= melt_inflation(type_two_inflation)
type_two_inflation = type_two_inflation.iloc[:, 2:]
type_two_inflation['Value'] = type_two_inflation['Value'].astype(float)
find_max_min_inflation_value(type_two_inflation, 'Same month of previous year')
# Table 3 type
type_three_inflation: pd.DataFrame = prep_inflation_v2('Table 3', 'Analogiczny okres narastający poprzedniego roku = 100', 9)
type_three_inflation= melt_inflation(type_three_inflation)
type_three_inflation = type_three_inflation.iloc[:, 2:]
type_three_inflation['Value'] = type_three_inflation['Value'].astype(float)
find_max_min_inflation_value(type_three_inflation, 'The analogous cumulative period of the previous year')
# Out:
# MIN VALUE FOR CATEGORY: December of previous year
#      Year     Month  Value       Data
# 368  2014  December   99.0 2014-12-01
# MAX VALUE FOR CATEGORY: December of previous year
#      Year     Month  Value       Data
# 393  1989  December  739.6 1989-12-01
#
#
# MIN VALUE FOR CATEGORY: Same month of previous year
#     Value       Data
# 40   98.4 2015-02-01
# MAX VALUE FOR CATEGORY: Same month of previous year
#      Value       Data
# 65  1283.1 1990-02-01
#
#
# MIN VALUE FOR CATEGORY: The analogous cumulative period of the previous year
#     Value       Data
# 35   98.5 2015-02-01
# MAX VALUE FOR CATEGORY: The analogous cumulative period of the previous year
#      Value       Data
# 92  1210.7 1990-03-01

# %% [markdown]
# **Task 4.2.**

# %%
def find_largest_value_for_each_year(df: pd.DataFrame, category: str) -> None:
  """
  Function to calculate max values for each year in data frame.
  Args:
    df (__pd.DataFrame__): DataFrame of given category.
    categor (__str__): String representation of category to propper print message.
  """
  print(f'Max values of inflation for each year for category: {category}')
  df['Year'] = df['Data'].dt.year
  df_max = df.groupby('Year')['Value'].max()
  print(df_max)

# %%
find_largest_value_for_each_year(type_one_inflation, 'December of previous year')
# Out:
# Max values of inflation for each year for category: December of previous year
# Year
# 1987    131.3
# 1988    173.9
# 1989    739.6
# 1990    349.3
# 1991    160.4
# 1992    144.3
# 1993    137.6
# 1994    129.5
# 1995    121.6
# 1996    118.5
# 1997    113.2
# 1998    108.6
# 1999    109.8
# 2000    108.5
# 2001    103.6
# 2002    101.7
# 2003    101.7
# 2004    104.4
# 2005    101.1
# 2006    101.6
# 2007    104.0
# 2008    103.4
# 2009    103.5
# 2010    103.1
# 2011    104.6
# 2012    102.6
# 2013    100.8
# 2014    100.3
# 2015    100.3
# 2016    100.8
# 2017    102.1
# 2018    101.1
# 2019    102.4
# Name: Value, dtype: float64

# %%
find_largest_value_for_each_year(type_two_inflation, 'Same month of previous year')
# Out:
# Max values of inflation for each year for category: Same month of previous year
# Year
# 1982     214.9
# 1983     167.3
# 1984     115.6
# 1985     116.7
# 1986     120.5
# 1987     131.3
# 1988     173.9
# 1989     739.6
# 1990    1283.1
# 1991     194.9
# 1992     146.5
# 1993     139.7
# 1994     136.1
# 1995     133.6
# 1996     121.0
# 1997     117.8
# 1998     114.2
# 1999     109.8
# 2000     111.6
# 2001     107.4
# 2002     103.5
# 2003     101.7
# 2004     104.6
# 2005     103.7
# 2006     101.6
# 2007     104.0
# 2008     104.8
# 2009     104.0
# 2010     103.5
# 2011     105.0
# 2012     104.3
# 2013     101.7
# 2014     100.7
# 2015      99.5
# 2016     100.8
# 2017     102.5
# 2018     102.0
# Name: Value, dtype: float64

# %%
find_largest_value_for_each_year(type_three_inflation, 'The analogous cumulative period of the previous year')
# Out:
# Max values of inflation for each year for category: The analogous cumulative period of the previous year
# Year
# 1987     125.2
# 1988     160.2
# 1989     351.1
# 1990    1210.7
# 1991     194.9
# 1992     145.4
# 1993     139.0
# 1994     132.5
# 1995     133.0
# 1996     121.0
# 1997     117.8
# 1998     113.9
# 1999     107.3
# 2000     110.4
# 2001     107.4
# 2002     103.4
# 2003     100.8
# 2004     103.5
# 2005     103.7
# 2006     101.0
# 2007     102.5
# 2008     104.4
# 2009     103.5
# 2010     103.5
# 2011     104.3
# 2012     104.2
# 2013     101.7
# 2014     100.6
# 2015      99.1
# 2016      99.4
# 2017     102.0
# 2018     101.9
# Name: Value, dtype: float64

# %% [markdown]
# **Task 4.3.**

# %%
def find_average_for_each_year(df: pd.DataFrame, category: str) -> None:
  """
  Function to calculate average values for each year in data frame.
  Args:
    df (__pd.DataFrame__): DataFrame of given category.
    categor (__str__): String representation of category to propper print message.
  """
  print(f'Average values of inflation for each year for category: {category}')
  df['Year'] = df['Data'].dt.year
  average = df.groupby('Year')['Value'].mean()
  print(average)

# %%
find_average_for_each_year(type_one_inflation, 'December of previous year')
# Out:
# Average values of inflation for each year for category: December of previous year
# Year
# 1987    118.783333
# 1988    144.175000
# 1989    287.741667
# 1990    272.491667
# 1991    137.591667
# 1992    124.675000
# 1993    118.175000
# 1994    114.400000
# 1995    113.033333
# 1996    111.158333
# 1997    107.850000
# 1998    106.458333
# 1999    105.216667
# 2000    105.491667
# 2001    102.500000
# 2002    100.933333
# 2003    100.841667
# 2004    102.650000
# 2005    100.525000
# 2006    101.000000
# 2007    102.058333
# 2008    102.375000
# 2009    102.758333
# 2010    101.875000
# 2011    102.916667
# 2012    101.958333
# 2013    100.466667
# 2014     99.791667
# 2015     99.883333
# 2016     99.841667
# 2017    100.991667
# 2018    100.608333
# 2019    101.520000
# Name: Value, dtype: float64

# %%
find_average_for_each_year(type_two_inflation, 'Same month of previous year')
# Out:
# Average values of inflation for each year for category: Same month of previous year
# Year
# 1982    200.441667
# 1983    126.025000
# 1984    113.091667
# 1985    113.900000
# 1986    117.433333
# 1987    125.275000
# 1988    157.166667
# 1989    324.308333
# 1990    912.150000
# 1991    171.566667
# 1992    142.850000
# 1993    135.475000
# 1994    132.191667
# 1995    128.125000
# 1996    119.908333
# 1997    114.950000
# 1998    111.866667
# 1999    107.258333
# 2000    110.091667
# 2001    105.475000
# 2002    101.941667
# 2003    100.841667
# 2004    103.491667
# 2005    102.133333
# 2006    101.033333
# 2007    102.491667
# 2008    104.216667
# 2009    103.450000
# 2010    102.583333
# 2011    104.266667
# 2012    103.700000
# 2013    100.900000
# 2014     99.975000
# 2015     99.066667
# 2016     99.416667
# 2017    101.975000
# 2018    101.666667
# Name: Value, dtype: float64

# %%
find_average_for_each_year(type_three_inflation, 'The analogous cumulative period of the previous year')
# Out:
# Average values of inflation for each year for category: The analogous cumulative period of the previous year
# Year
# 1987     121.700000
# 1988     148.583333
# 1989     215.125000
# 1990    1064.241667
# 1991     178.416667
# 1992     142.075000
# 1993     137.050000
# 1994     131.641667
# 1995     131.175000
# 1996     120.341667
# 1997     116.183333
# 1998     113.141667
# 1999     106.550000
# 2000     110.225000
# 2001     106.425000
# 2002     102.708333
# 2003     100.550000
# 2004     102.533333
# 2005     102.908333
# 2006     100.766667
# 2007     102.091667
# 2008     104.216667
# 2009     103.383333
# 2010     102.750000
# 2011     104.058333
# 2012     103.991667
# 2013     101.091667
# 2014     100.350000
# 2015      98.783333
# 2016      99.150000
# 2017     101.933333
# 2018     101.650000
# Name: Value, dtype: float64
